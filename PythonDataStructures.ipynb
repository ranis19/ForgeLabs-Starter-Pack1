# %%
#List
fruits=['apple','banana','cherry']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#Tuple
quantity=(20,25,30)
print(quantity)
# Out:
# (20, 30, 40, 50)

# %%
#Set
colours={'red','yellow','maroon'}
print(colours)
# Out:
# {'blue', 'red', 'yellow'}

# %%
#Dictionary
data={'fruits':['apple','banana','cherry'],'quantity':(20,25,30),'colours':['red','yellow','maroon']}
print(data)
# Out:
# {'fruits': ['apple', 'banana', 'cherry'], 'quantity': (20, 25, 30), 'colours': ['red', 'yellow', 'maroon']}
